# %% [markdown]
# vs-code에서 가상환경셋팅을 할때 : ctrl + shift + p

# %%
print("헬로")
# Out:
# 헬로

# %%
import ollama

response = ollama.chat(
    model="exaone3.5:7.8b",
    messages=[
        {
            "role": "user",
            "content": "로컬 llm에 대해 설명해줘."
        }
    ]
)

print(response["message"]["content"])
# Out:
# 로컬 LLM, 또는 Local Language Model은 주로 특정 지역이나 특정 사용자 기반에 맞춤화된 언어 모델을 의미합니다. 이 모델들은 다음과 같은 특징을 가지고 있습니다:
#
# 1. **지역 특화**: 특정 지역의 언어, 방언, 문화적 맥락을 더 잘 이해하도록 설계됩니다. 예를 들어, 한국어 로컬 LLM은 한국어의 지역적 변형이나 특정 지역 특유의 표현을 효과적으로 처리할 수 있습니다.
#
# 2. **데이터 기반**: 해당 지역이나 사용자 그룹에서 수집된 데이터로 훈련되므로, 그 지역이나 그룹에 특화된 지식과 표현을 더 잘 반영합니다. 이는 모델의 응답 정확도와 관련성을 높일 수 있습니다.
#
# 3. **개인화**: 사용자의 특정 요구사항이나 선호도에 맞춰 조정될 수 있어 개인화된 서비스 제공이 가능합니다.
#
# 4. **자원 효율성**: 대규모 글로벌 모델에 비해 훈련 및 실행에 필요한 컴퓨팅 자원이 적을 수 있습니다. 지역 데이터만을 활용하므로, 데이터 처리와 모델 유지 관리 측면에서 효율적일 수 있습니다.
#
# ### 예시
# - **한국어 로컬 LLM**: 특정 지역의 방언이나 현지 문화적 맥락을 이해하는 데 특화된 한국어 처리 모델입니다. 예를 들어, 경상도 방언을 주로 다루는 모델은 해당 지역 사용자에게 더 자연스러운 대화 경험을 제공할 수 있습니다.
#
# 로컬 LLM은 특정 지역이나 사용자 그룹에 맞춘 서비스 제공을 위해 유용하며, 특히 지역적 특성이 중요한 커뮤니케이션이나 정보 제공 분야에서 큰 이점을 제공합니다.
